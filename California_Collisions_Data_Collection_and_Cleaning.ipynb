# %% [markdown]
# # California Collisions Data Cleaning

# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
con = sqlite3.connect('/content/switrs.sqlite')

# %% [markdown]
# # Drunk collisions per county

# %%
new_data = pd.read_sql_query('''
                          SELECT
                          county_location, party_sobriety 
                          FROM collisions
                          INNER JOIN parties
                          ON parties.case_id = collisions.case_id
                          WHERE '2020-01-01' > collision_date
                          AND collision_date >= '2010-01-01'
                          AND parties.party_type = 'driver'
                          AND parties.at_fault = 1
                         ''', con)

# %%
def county_groups(dataframe):
    sober_filter = dataframe['party_sobriety'] != 'had been drinking, under influence'
    sober_data = dataframe.loc[sober_filter]['county_location'].value_counts()\
    .rename_axis('county_name').reset_index(name='number_of_sober_collisions')
    drunk_filter = dataframe['party_sobriety'] == 'had been drinking, under influence'
    drunk_data = dataframe.loc[drunk_filter]['county_location'].value_counts()\
    .rename_axis('county_name').reset_index(name='number_of_drunk_collisions')
    return pd.merge(sober_data, drunk_data, on = 'county_name')

# %%
collisions = county_groups(new_data)
collisions['county_name'] = collisions['county_name'].apply(lambda x: x.title() + ' County')

# %%
collisions['Proportion_of_drunk_accidents (%)'] = round(collisions['number_of_drunk_collisions'] 
                                                        / collisions['number_of_sober_collisions'] * 100, 2)

# %%
collisions = collisions.sort_values('county_name')

# %%
collisions = collisions.set_index('county_name')

# %%
collisions
# Out:
#                         number_of_sober_collisions  ...  Proportion_of_drunk_accidents (%)
# county_name                                         ...
# Alameda County                              178014  ...                               6.50
# Alpine County                                  607  ...                               9.06
# Amador County                                 3848  ...                              11.88
# Butte County                                 16083  ...                              14.50
# Calaveras County                              4515  ...                              13.02
# Colusa County                                 2723  ...                               9.99
# Contra Costa County                          81915  ...                               8.79
# Del Norte County                              2495  ...                              10.50
# El Dorado County                             12973  ...                              16.23
# Fresno County                                60144  ...                              11.28
# Glenn County                                  2361  ...                              12.37
# Humboldt County                              15610  ...                              12.90
# Imperial County                               9761  ...                               8.80
# Inyo County                                   2367  ...                               8.96
# Kern County                                  77366  ...                              11.22
# Kings County                                 12671  ...                               9.04
# Lake County                                   5130  ...                              17.33
# Lassen County                                 2441  ...                               8.64
# Los Angeles County                         1151806  ...                               6.66
# Madera County                                17440  ...                              11.16
# Marin County                                 24231  ...                               8.39
# Mariposa County                               1794  ...                              10.14
# Mendocino County                             10129  ...                              12.62
# Merced County                                29280  ...                               9.47
# Modoc County                                   749  ...                              12.28
# Mono County                                   1796  ...                               8.74
# Monterey County                              46267  ...                               9.16
# Napa County                                  13408  ...                              12.74
# Nevada County                                 9069  ...                              12.49
# Orange County                               273614  ...                               9.59
# Placer County                                27970  ...                               8.95
# Plumas County                                 1954  ...                              15.25
# Riverside County                            194307  ...                               8.99
# Sacramento County                           151071  ...                               8.14
# San Benito County                             5306  ...                              11.50
# San Bernardino County                       220896  ...                               8.71
# San Diego County                            204859  ...                              11.26
# San Francisco County                         51814  ...                               6.20
# San Joaquin County                           75068  ...                               8.51
# San Luis Obispo County                       29177  ...                              11.29
# San Mateo County                             61954  ...                               8.68
# Santa Barbara County                         44748  ...                              10.68
# Santa Clara County                          131655  ...                               7.47
# Santa Cruz County                            27675  ...                              12.10
# Shasta County                                14743  ...                              12.14
# Sierra County                                  538  ...                              12.27
# Siskiyou County                               4007  ...                              11.33
# Solano County                                38685  ...                               9.09
# Sonoma County                                45501  ...                              12.14
# Stanislaus County                            50995  ...                               9.96
# Sutter County                                 8120  ...                              10.33
# Tehama County                                 5640  ...                              12.09
# Trinity County                                1643  ...                              15.76
# Tulare County                                43146  ...                               9.58
# Tuolumne County                               6567  ...                              11.98
# Ventura County                               74208  ...                               8.89
# Yolo County                                  19006  ...                               8.22
# Yuba County                                   6363  ...                              10.15
#
# [58 rows x 3 columns]

# %% [markdown]
# # Drunk Collisions per Race

# %%
race_data = pd.read_sql_query('''SELECT collisions.county_location, parties.party_race, count(parties.party_race)
                                 FROM collisions 
                                 INNER JOIN parties ON collisions.case_id = parties.case_id
                                 WHERE parties.party_type = 'driver'
                                 AND parties.party_sobriety = 
                                 'had been drinking, under influence'
                                 AND '2020-01-01' > collisions.collision_date 
                                 AND collisions.collision_date >= '2010-01-01'
                                 AND parties.at_fault = 1
                                 GROUP BY county_location, party_race''', con)

# %%
race_data.dropna(inplace = True)

# %%
race_data.head(10)
# Out:
#    county_location party_race  count(parties.party_race)
# 1          alameda      asian                        751
# 2          alameda      black                       2176
# 3          alameda   hispanic                       4125
# 4          alameda      other                        769
# 5          alameda      white                       3426
# 6           alpine      black                          3
# 7           alpine   hispanic                          4
# 8           alpine      other                          4
# 9           alpine      white                         44
# 11          amador      asian                          2

# %%
def race_groups_dataframe(county):
  dic = {}
  for i in race_data['party_race'].unique():
    if i not in race_data['party_race'][race_data['county_location'] == county].values:
      dic[i] = 0
    else:
      dic[i] = race_data['count(parties.party_race)'][(race_data['county_location'] == county) & (race_data['party_race'] == i)].values[0]
  return dic.values()

# %%
index = [i.title() + ' County' for i in race_data['county_location'].unique()]

# %%
drunk_race_groups_split = pd.DataFrame([race_groups_dataframe(i) for i in race_data['county_location'].unique()], index =
                                      index, columns = race_data['party_race'].unique())

# %%
drunk_race_groups_split
# Out:
#                         asian  black  hispanic  other  white
# Alameda County            751   2176      4125    769   3426
# Alpine County               0      3         4      4     44
# Amador County               2      7        46      9    386
# Butte County               33     64       356     61   1758
# Calaveras County            3      8        62      7    507
# Colusa County               2      7       128     11    120
# Contra Costa County       227   1082      2314    419   2991
# Del Norte County            5      2        24     33    194
# El Dorado County           17     28       182     70   1743
# Fresno County             281    280      4138    181   1820
# Glenn County                4     10       106      8    160
# Humboldt County            33     46       206    185   1497
# Imperial County             2     18       627     17    179
# Inyo County                 3      4        33     43    125
# Kern County                60    506      4859    145   2999
# Kings County                6     44       739     26    298
# Lake County                 8     24       155     56    626
# Lassen County               0      2        23     11    170
# Los Angeles County       3062   8042     44635   3039  15814
# Madera County              13     43      1175     67    621
# Marin County               29     90       648     67   1176
# Mariposa County             1      2        17      7    155
# Mendocino County            5     23       278     71    884
# Merced County              77    117      1774     71    690
# Modoc County                0      0        15      7     70
# Mono County                 2      1        20      9    121
# Monterey County            42    108      2795     56   1145
# Napa County                34     47       716     39    850
# Nevada County               7     18        80     24    986
# Orange County            1525    672     10315    798   9882
# Placer County              28     75       323     69   1912
# Plumas County               2      5        18     12    258
# Riverside County          242   1262      9674    380   5649
# Sacramento County         762   1833      3161    588   5687
# San Benito County           3     10       378      8    202
# San Bernardino County     246   1799     10865    378   5596
# San Diego County          627   1665      8836    726  10801
# San Francisco County      391    373      1094    217   1100
# San Joaquin County        255    575      2917    274   2203
# San Luis Obispo County     27     44       907     60   2192
# San Mateo County          319    246      2052    381   2027
# Santa Barbara County       42     85      2663    115   1797
# Santa Clara County        793    426      4485    566   3181
# Santa Cruz County          44     54      1288     97   1826
# Shasta County              26     37       118     48   1504
# Sierra County               1      0         4      2     59
# Siskiyou County             3     10        36     33    361
# Solano County             103    654      1000    232   1457
# Sonoma County              66    154      1817    136   3234
# Stanislaus County          93    208      2509    136   1933
# Sutter County              20     30       299     57    410
# Tehama County               7     11       168     19    467
# Trinity County              1      0        16      8    230
# Tulare County              65     69      2832     53    915
# Tuolumne County             3      6        64     17    685
# Ventura County             67    158      3234    141   2920
# Yolo County                45    100       619     82    668
# Yuba County                12     21       137     29    434

# %% [markdown]
# # Drunk Collisions per Age Group

# %%
age_ranges = list(range(16, 84, 4))
age_strings = []
for i in range(len(age_ranges) - 1):
  age_strings.append(f"WHEN parties.party_age >= {age_ranges[i]} AND parties.party_age < {age_ranges[i + 1]} \
  THEN '{age_ranges[i]} - {age_ranges[i + 1] - 1}'")

# %%
strings = ' '.join(age_strings)

# %%
drunk_age_group_query = f'''
                           SELECT collisions.county_location, Count(parties.party_age) AS 'Age_Groups', 
                           CASE {strings} 
                           WHEN parties.party_age >= 80 THEN 'Over 80'
                           END AS Ages_groups
                           FROM parties
                           INNER JOIN collisions 
                           ON collisions.case_id = parties.case_id
                           WHERE parties.party_type = 'driver'
                           AND parties.party_sobriety = 
                           'had been drinking, under influence'
                           AND '2020-01-01' > collisions.collision_date 
                           AND collisions.collision_date >= '2010-01-01'
                           AND parties.at_fault = 1
                           GROUP BY county_location, ages_groups
                       '''

# %%
drunk_age_groups = pd.read_sql_query(drunk_age_group_query, con)

# %%
drunk_age_groups.dropna(inplace = True)

# %%
index = [i.title() + ' County' for i in drunk_age_groups['county_location'].unique()]

# %%
def age_groups_dataframe(county):
  dic = {}
  for i in drunk_age_groups['Ages_groups'].unique():
    if i not in drunk_age_groups['Ages_groups'][drunk_age_groups['county_location'] == county].values:
      dic[i] = 0
    else:
      dic[i] = drunk_age_groups['Age_Groups'][(drunk_age_groups['county_location'] == county) & (drunk_age_groups['Ages_groups'] == i)].values[0]
  return dic.values()

# %%
drunk_age_groups_split = pd.DataFrame([age_groups_dataframe(i) for i in drunk_age_groups['county_location'].unique()], index =
                                      index, columns = drunk_age_groups['Ages_groups'].unique())

# %%
drunk_age_groups_split
# Out:
#                         16 - 19  20 - 23  24 - 27  ...  72 - 75  76 - 79  Over 80
# Alameda County              495     1899     2044  ...       45       19       16
# Alpine County                 2        8        9  ...        0        0        0
# Amador County                13       61       59  ...        7        1        3
# Butte County                147      504      343  ...       19       11        3
# Calaveras County             21       81       70  ...        7        3        0
# Colusa County                17       59       26  ...        1        1        1
# Contra Costa County         398     1170     1185  ...       26       18       17
# Del Norte County             22       32       33  ...        3        2        0
# El Dorado County            119      318      291  ...       11       13        3
# Fresno County               459     1384     1242  ...       17        9        5
# Glenn County                 16       61       49  ...        4        1        0
# Humboldt County              99      339      346  ...       16        4        3
# Imperial County              48      174      129  ...        3        3        1
# Inyo County                  12       24       36  ...        1        5        0
# Kern County                 543     1629     1530  ...       36       14       15
# Kings County                 75      234      199  ...        3        2        0
# Lake County                  53      127      123  ...        9        1        1
# Lassen County                 8       25       26  ...        0        2        1
# Los Angeles County         3158    13952    14051  ...      256      123      115
# Madera County               141      370      341  ...        6        6        3
# Marin County                120      286      302  ...       22       12        6
# Mariposa County               5       30       26  ...        2        2        0
# Mendocino County             63      195      179  ...        7        3        0
# Merced County               156      562      486  ...       10        2        6
# Modoc County                  7       13       10  ...        0        0        0
# Mono County                   4       18       26  ...        0        0        0
# Monterey County             294      835      787  ...       18        5       12
# Napa County                  99      293      255  ...        5        7        5
# Nevada County                36      144      175  ...        3        3        1
# Orange County              1346     5264     4693  ...      106       51       33
# Placer County               135      420      416  ...       12       12        7
# Plumas County                15       45       40  ...        1        1        2
# Riverside County            950     3533     3140  ...       84       38       41
# Sacramento County           567     2092     2132  ...       48       25       19
# San Benito County            44      120       98  ...        2        2        0
# San Bernardino County       963     3912     3505  ...       54       23       23
# San Diego County           1193     4770     4318  ...       83       58       43
# San Francisco County         69      484      638  ...       13        4        3
# San Joaquin County          334     1130     1097  ...       34       17       10
# San Luis Obispo County      192      667      540  ...       17        8       10
# San Mateo County            238      935      925  ...       28       18       10
# Santa Barbara County        356     1016      839  ...       27       12       14
# Santa Clara County          575     1943     1818  ...       36       13       24
# Santa Cruz County           220      646      533  ...       24        1        0
# Shasta County               109      283      234  ...       10        5        6
# Sierra County                 0        6        8  ...        0        0        0
# Siskiyou County              21       56       65  ...        3        2        2
# Solano County               163      603      582  ...       19       10        5
# Sonoma County               299      974      846  ...       30       23       14
# Stanislaus County           265      952      903  ...       19       10       10
# Sutter County                56      158      141  ...        2        2        0
# Tehama County                33       95      103  ...        2        3        4
# Trinity County               11       33       33  ...        1        1        0
# Tulare County               318      886      763  ...       20        4        6
# Tuolumne County              40      121       95  ...        6        3        2
# Ventura County              453     1267     1122  ...       30       13       13
# Yolo County                  96      328      244  ...        6        3        0
# Yuba County                  29      102      110  ...        4        3        1
#
# [58 rows x 17 columns]
